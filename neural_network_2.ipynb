# %%
# !pip install -U keras-tuner

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
# Dense: to add layers (hidden,output)
from tensorflow.keras.layers import Dense
from tensorflow.keras import Sequential
import keras_tuner as kf
# sequential: to add layers in sequence, to initialize ann model i.e, initially random weight will be assigned
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("/content/Churn_Modelling.csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.drop(columns=['RowNumber','CustomerId','Surname'],inplace=True)

# %%
df=pd.get_dummies(data=df,columns=['Geography','Gender'])
df
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_France  \
# 0                  1        101348.88       1              True
# ...

# %%
sc=StandardScaler()
x=df.drop(columns=['Exited'])
y=df['Exited']

# %%
x=sc.fit_transform(x)
x
# Out:
# array([[-0.32622142,  0.29351742, -1.04175968, ..., -0.57380915,
#          1.09598752, -1.09598752],
#        [-0.44003595,  0.19816383, -1.38753759, ...,  1.74273971,
#          1.09598752, -1.09598752],
#        [-1.53679418,  0.29351742,  1.03290776, ..., -0.57380915,
#          1.09598752, -1.09598752],
#        ...,
#        [ 0.60498839, -0.27860412,  0.68712986, ..., -0.57380915,
#          1.09598752, -1.09598752],
#        [ 1.25683526,  0.29351742, -0.69598177, ..., -0.57380915,
#         -0.91241915,  0.91241915],
#        [ 1.46377078, -1.04143285, -0.35020386, ..., -0.57380915,
#          1.09598752, -1.09598752]])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=1)

# %%
ann=Sequential()

ann.add(Dense(units=10,activation='relu'))# hidden layer1
ann.add(Dense(units=1,activation='sigmoid'))# output layer


ann.compile(optimizer='adadelta',loss='binary_crossentropy',metrics=['accuracy'])

ann.fit(x_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4133 - loss: 0.8746
# Epoch 2/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4064 - loss: 0.8803
# Epoch 3/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4094 - loss: 0.8738
# Epoch 4/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4080 - loss: 0.8689
# Epoch 5/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4080 - loss: 0.8727
# Epoch 6/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.4117 - loss: 0.8670
# Epoch 7/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.4064 - loss: 0.8733
# Epoch 8/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4149 - loss: 0.8633
# Epoch 9/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4165 - loss: 0.8628
# Epoch 10/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4175 - loss: 0.8595
# Epoch 11/100
# ...

# %%
yp=ann.predict(x_test)
yp=yp>0.5
yp
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[ True],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [ True],
#        [False]])

# %%
print(classification_report(y_test,yp))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.50      0.62      1585
#            1       0.24      0.61      0.35       415
#
#     accuracy                           0.52      2000
#    macro avg       0.54      0.55      0.48      2000
# weighted avg       0.71      0.52      0.57      2000

# %%
ann.evaluate(x_train,y_train)
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5202 - loss: 0.7327
# [0.7362847328186035, 0.515874981880188]

# %% [markdown]
# ## **Hyperparameter Tuning**

# %%
list(range(8,128,8))
# Out:
# [8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120]

# %%
def hyper(hp):
  model=Sequential()

  # add input layer
  model.add(Dense(hp.Int('units0',min_value=8,max_value=128,step=8),
                  activation=hp.Choice('activation0',values=['relu','tanh','sigmoid']),
                  input_dim=13))
  #add additional hidden layers
  for i in range(1,hp.Int('num_layers',min_value=1,max_value=10)):
    model.add(Dense(hp.Int('units'+str(i),min_value=8,max_value=128,step=8),
                  activation=hp.Choice('activation'+str(i),values=['relu','tanh','sigmoid'])))

  # add output layer
  model.add(Dense(units=1,activation='sigmoid'))

  # Compile the model
  model.compile(optimizer=hp.Choice('optimizer',values=['adam','rmsprop','sgd']),
                loss='binary_crossentropy',
                metrics=['accuracy'])
  return model

# %%
tuner=kf.RandomSearch(hyper,
                      objective='val_accuracy',
                      max_trials=3)
# Out:
# Reloading Tuner from ./untitled_project/tuner0.json

# %%
tuner.search(x_train,y_train,epochs=3,validation_data=(x_test,y_test))

# %%
tuner.get_best_hyperparameters()[0].values# we will give 1st model where accuracy is high
# each of the 13 input features is connected to all 120 neurons in the input layer
# this means that each of the 120 neurons will recieve all 13 input values
# and apply a weighted sum and activation function to compute output
# Out:
# {'units0': 32,
#  'activation0': 'relu',
#  'num_layers': 4,
#  'optimizer': 'sgd',
#  'units1': 128,
#  'activation1': 'sigmoid',
#  'units2': 112,
#  'activation2': 'tanh',
#  'units3': 40,
#  'activation3': 'sigmoid',
#  'units4': 48,
#  'activation4': 'sigmoid',
#  'units5': 32,
#  'activation5': 'tanh',
#  'units6': 40,
#  'activation6': 'sigmoid',
#  'units7': 80,
#  'activation7': 'relu',
#  'units8': 104,
#  'activation8': 'tanh',
#  'units9': 64,
#  'activation9': 'sigmoid'}

# %%
tuned_model=tuner.get_best_models(num_models=1)[0]

# %%
tuned_model.fit(x_train,y_train,epochs=50,validation_data=(x_test,y_test))
# Out:
# Epoch 1/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7939 - loss: 0.5084 - val_accuracy: 0.7925 - val_loss: 0.5096
# Epoch 2/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7956 - loss: 0.5056 - val_accuracy: 0.7925 - val_loss: 0.5087
# Epoch 3/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7923 - loss: 0.5090 - val_accuracy: 0.7925 - val_loss: 0.5079
# Epoch 4/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7950 - loss: 0.5044 - val_accuracy: 0.7925 - val_loss: 0.5066
# Epoch 5/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7986 - loss: 0.4984 - val_accuracy: 0.7925 - val_loss: 0.5061
# Epoch 6/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8023 - loss: 0.4930 - val_accuracy: 0.7925 - val_loss: 0.5042
# Epoch 7/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7976 - loss: 0.4981 - val_accuracy: 0.7925 - val_loss: 0.5029
# Epoch 8/50
# ...

# %%
tuned_model.evaluate(x_train,y_train)#training accuracy
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8467 - loss: 0.3696
# [0.3688991367816925, 0.846750020980835]

# %%
tuned_model.evaluate(x_test,y_test)#training accuracy
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8460 - loss: 0.3732
# [0.3654666244983673, 0.8479999899864197]
